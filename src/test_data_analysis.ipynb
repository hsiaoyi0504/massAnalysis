# %%
import pandas as pd

# %%
data=pd.read_csv('../data/search_result/sample3/20151119---SAMPLE3-PHREE-100XMEOH-MOBILITY_dt_temp_Apex3DIons1.csv')
data=data[(data.adduct.isin(['M+H','M+Na','M+K']))]

# %%
pd.value_counts(data['compound_id'])
# Out:
# HMDB38242     3
# HMDB31773     2
# HMDB41057     2
# HMDB37044     2
# HMDB36754     2
# HMDB06036     2
# HMDB32669     2
# HMDB38885     2
# HMDB36368     2
# HMDB33872     2
# HMDB39687     2
# HMDB06254     2
# HMDB31085     2
# HMDB36147     2
# HMDB31963     2
# HMDB40176     2
# HMDB39382     2
# HMDB36042     2
# HMDB31042     2
# HMDB29691     2
# HMDB40180     2
# HMDB31006     2
# HMDB05943     2
# HMDB02172     2
# HMDB36812     2
# HMDB29862     2
# HMDB35063     2
# HMDB39702     2
# HMDB32601     2
# HMDB31047     2
#              ..
# HMDB13331     1
# HMDB31799     1
# HMDB37072     1
# HMDB33654     1
# HMDB29852     1
# HMDB34372     1
# HMDB38146     1
# HMDB60992     1
# HMDB40864     1
# HMDB33505     1
# ECMDB23250    1
# HMDB01441     1
# HMDB01366     1
# HMDB38190     1
# HMDB60127     1
# HMDB14021     1
# HMDB31958     1
# HMDB34416     1
# HMDB40189     1
# HMDB35567     1
# HMDB31579     1
# HMDB06768     1
# HMDB11162     1
# HMDB35090     1
# ...

# %%
pd.value_counts(data['formula'])
# Out:
# C15H24O       51
# C20H28O3      50
# C15H26O       43
# C10H14O2      42
# C15H22O2      38
# C8H16O2       36
# C15H24O2      33
# C15H22O       30
# C20H32O2      26
# C29H48O       23
# C9H10O        19
# C18H30O3      19
# C30H46O3      18
# C30H50O3      18
# C7H12O        17
# C6H10O        15
# C30H48O5      14
# C20H30O2      14
# C10H15NO      13
# C21H32O2      12
# C9H12O2       12
# C8H9NO        12
# C16H28O8      10
# C10H14O3      10
# C11H17NO       9
# C17H26O2       9
# C20H26O3       9
# C17H34O2       9
# C5H11NO2       9
# C29H48O2       9
#               ..
# C22H25N3O3     1
# C19H34O        1
# C13H20N2O2     1
# C26H43NO       1
# C34H54O8       1
# C22H30O        1
# C20H28NO2      1
# C15H32O6       1
# C8H12S         1
# C6H6N4         1
# C24H29NO3      1
# C10H16NO       1
# C16H20N2O      1
# C15H20N2O2     1
# C12H26O3       1
# C25H33NO5      1
# C11H9NO3       1
# C21H37NO5      1
# C20H29FO3      1
# C22H28N2O      1
# C20H30         1
# ...

# %%
data[(data.formula.isin(['C15H24O']))]
# Out:
#      query_mass compound_id  formula  compound_mass adduct adduct_type  \
# 593    259.1663   HMDB35645  C15H24O     220.182715    M+K           +
# 594    259.1663   HMDB38123  C15H24O     220.182715    M+K           +
# 595    259.1663   HMDB38134  C15H24O     220.182715    M+K           +
# 596    259.1663   HMDB39532  C15H24O     220.182715    M+K           +
# 597    259.1663   HMDB35718  C15H24O     220.182715    M+K           +
# 598    259.1663   HMDB38193  C15H24O     220.182715    M+K           +
# 599    259.1663   HMDB36717  C15H24O     220.182715    M+K           +
# 600    259.1663   HMDB38208  C15H24O     220.182715    M+K           +
# 601    259.1663   HMDB36788  C15H24O     220.182715    M+K           +
# 602    259.1663   HMDB38160  C15H24O     220.182715    M+K           +
# 603    259.1663   HMDB35704  C15H24O     220.182715    M+K           +
# 604    259.1663   HMDB37069  C15H24O     220.182715    M+K           +
# ...

# %%
pd.value_counts(data[(data.formula.isin(['C27H46O2']))]['compound_id'])
# Out:
# Series([], Name: compound_id, dtype: int64)
